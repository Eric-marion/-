# %% [markdown]
# ### 多进程分布式： 加速爬虫

# %%
import multiprocessing as hmp
import time
from urllib.request import urlopen, urljoin
from bs4 import BeautifulSoup
import re

base_url = "https://morvanzhou.github.io"
# don't over crawl the website or you may never visit again
# 爬过的内容不爬第二次
if base_url != "https://morvanzhou.github.io":
    restricted_crawl = True
else:
    restricted_crawl = False

# %% [markdown]
# ## Create a crawl function to open a url in parallel
# ### 创建一个抓取函数来并行打开文件

# %%
def crawl(url):
    response = urlopen(url)
    time.sleep(0.1)   # slightly delay for download
    return response.read().decode()

# %% [markdown]
# ## Create a parse function to find all results we need in parallel
# ### 创建一个解析函数来并行寻找我们所需要的结果

# %%
def parse(html):
    soup = BeautifulSoup(html,'lxml')
    urls = soup.find_all('a',{"href": re.compile('^/.+?/$')})
    title = soup.find('h1').get_text().strip()
    page_urls = set([urljoin(base_url,url['href']) for url in urls])
    url = soup.find('meta',{'property':"og:url"})['content']
    return title, page_urls, url

# %% [markdown]
# ## Normal way
# #### Do not use multiprocessing, test the speed. Firstly, set what urls we have already seen and what we haven't in a python set

# %%
unseen = set([base_url,])
seen = set()

count, t1 = 1,time.time()

while len(unseen)!=0:   # still get some url to visit
    if restricted_crawl and len(seen) > 20:
        break
        
    print('\nDistricted Crawling...')
    htmls = [crawl(url) for url in unseen]
    
    print('\nDistrcted Parsing...')
    results = [parse(html) for html in htmls]
    
    print('\nAnalysing...')
    seen.update(unseen)     # seen the crawled
    unseen.clear()          #nothing unseen
    
    for title, page_urls, url in results:
        print(count, title, url)
        count+=1
        unseen.update(page_urls - seen) # get new url to crawl
print('Total time: %.1f s' %(time.time()-t1, ))
# Out:
# Districted Crawling...
#
# Distrcted Parsing...
#
# Analysing...
# 1 教程 https://morvanzhou.github.io/
#
# Districted Crawling...
#
# Distrcted Parsing...
#
# Analysing...
# 2 为了更优秀 https://morvanzhou.github.io/support/
# 3 高级爬虫: 让 Selenium 控制你的浏览器帮你爬 https://morvanzhou.github.io/tutorials/data-manipulation/scraping/5-01-selenium/
# 4 Git 版本管理 教程系列 https://morvanzhou.github.io/tutorials/others/git/
# 5 Linux 简易教学 https://morvanzhou.github.io/tutorials/others/linux-basic/
# 6 迁移学习 Transfer Learning https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-16-transfer-learning/
# 7 迁移学习 Transfer Learning https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/2-9-transfer-learning/
# 8 Pytorch 教程系列 https://morvanzhou.github.io/tutorials/machine-learning/torch/
# 9 高级爬虫: 高效无忧的 Scrapy 爬虫库 https://morvanzhou.github.io/tutorials/data-manipulation/scraping/5-02-scrapy/
# 10 强化学习 Reinforcement Learning 教程系列 https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/
# 11 Python基础 教程系列 https://morvanzhou.github.io/tutorials/python-basic/
# 12 Threading 多线程教程系列 https://morvanzhou.github.io/tutorials/python-basic/threading/
# 13 Numpy & Pandas 教程系列 https://morvanzhou.github.io/tutorials/data-manipulation/np-pd/
# 14 网页爬虫教程系列 https://morvanzhou.github.io/tutorials/data-manipulation/scraping/
# 15 有趣的机器学习系列 https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/
# 16 Why? https://morvanzhou.github.io/tutorials/data-manipulation/scraping/1-00-why/
# 17 机器学习实践 https://morvanzhou.github.io/tutorials/machine-learning/ML-practice/
# 18 近期更新 https://morvanzhou.github.io/recent-posts/
# 19 Tkinter GUI 教程系列 https://morvanzhou.github.io/tutorials/python-basic/tkinter/
# 20 其他教学系列 https://morvanzhou.github.io/tutorials/others/
# 21 Sklearn 通用机器学习 教程系列 https://morvanzhou.github.io/tutorials/machine-learning/sklearn/
# 22 Theano 教程系列 https://morvanzhou.github.io/tutorials/machine-learning/theano/
# 23 Matplotlib 画图教程系列 https://morvanzhou.github.io/tutorials/data-manipulation/plt/
# 24 推荐学习顺序 https://morvanzhou.github.io/learning-steps/
# 25 Tensorflow 教程系列 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/
# 26 说吧~ https://morvanzhou.github.io/discuss/
# 27 数据处理教程系列 https://morvanzhou.github.io/tutorials/data-manipulation/
# 28 机器学习系列 https://morvanzhou.github.io/tutorials/machine-learning/
# 29 关于莫烦 https://morvanzhou.github.io/about/
# 30 Keras 教程系列 https://morvanzhou.github.io/tutorials/machine-learning/keras/
# 31 multiprocessing 多进程教程系列 https://morvanzhou.github.io/tutorials/python-basic/multiprocessing/
# 32 进化算法 Evolutionary Strategies 教程系列 https://morvanzhou.github.io/tutorials/machine-learning/evolutionary-algorithm/
# 33 基础教程系列 https://morvanzhou.github.io/tutorials/python-basic/basic/
#
# Districted Crawling...
#
# Distrcted Parsing...
#
# Analysing...
# 34 怎么样从 MacOS 或 Linux 通过 SSH 远程 Linux https://morvanzhou.github.io/tutorials/others/linux-basic/4-01-ssh-from-linux-or-mac/
# 35 什么是 DQN https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/4-1-A-DQN/
# 36 什么是激励函数 (Activation Function) https://morvanzhou.github.io/tutorials/machine-learning/theano/2-4-A-activation-function/
# 37 什么是神经网络进化 (Neuro-Evolution) https://morvanzhou.github.io/tutorials/machine-learning/evolutionary-algorithm/4-00-neuro-evolution/
# 38 sklearn 常用属性与功能 https://morvanzhou.github.io/tutorials/machine-learning/sklearn/2-4-model-attributes/
# 39 神经网络 梯度下降 https://morvanzhou.github.io/tutorials/machine-learning/torch/1-1-C-gradient-descent/
# 40 遗传算法 (Genetic Algorithm) https://morvanzhou.github.io/tutorials/machine-learning/evolutionary-algorithm/2-00-genetic-algorithm/
# 41 什么是自编码 (Autoencoder) https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-11-A-autoencoder/
# 42 zip lambda map https://morvanzhou.github.io/tutorials/python-basic/basic/13-03-zip-lambda-map/
# 43 Double DQN (Tensorflow) https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/4-5-double_DQN/
# 44 class 类 init 功能 https://morvanzhou.github.io/tutorials/python-basic/basic/09-2-class-init/
# 45 神经网络 梯度下降 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/1-1-C-gradient-descent/
# 46 快速了解 Ubuntu 17.10 基本界面 https://morvanzhou.github.io/tutorials/others/linux-basic/1-3-system-overview/
# 47 Numpy 的创建 array https://morvanzhou.github.io/tutorials/data-manipulation/np-pd/2-2-np-array/
# 48 共享内存 shared memory https://morvanzhou.github.io/tutorials/python-basic/multiprocessing/6-shared-memory/
# 49 储存进程结果 Queue https://morvanzhou.github.io/tutorials/python-basic/threading/4-queue/
# 50 Tensorflow 2017 更新 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-14-tf2017/
# 51 copy & deepcopy 浅复制 & 深复制 https://morvanzhou.github.io/tutorials/python-basic/basic/13-04-copy/
# 52 从头开始做一个机器手臂5 完善测试 https://morvanzhou.github.io/tutorials/machine-learning/ML-practice/RL-build-arm-from-scratch5/
# 53 什么是批标准化 (Batch Normalization) https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-13-A-batch-normalization/
# 54 Pandas plot 出图 https://morvanzhou.github.io/tutorials/data-manipulation/np-pd/3-8-pd-plot/
# 55 Bar 柱状图 https://morvanzhou.github.io/tutorials/data-manipulation/plt/3-2-Bar/
# 56 Entry & Text 输入, 文本框 https://morvanzhou.github.io/tutorials/python-basic/tkinter/2-02-entry-text/
# 57 Placeholder 传入值 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/2-5-placeholde/
# 58 OpenAI gym 环境库 https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/4-4-gym/
# 59 if elif else 判断 https://morvanzhou.github.io/tutorials/python-basic/basic/04-3-if-elif-else/
# 60 tick 能见度 https://morvanzhou.github.io/tutorials/data-manipulation/plt/2-7-tick-visibility/
# 61 什么是 LSTM 循环神经网络 https://morvanzhou.github.io/tutorials/machine-learning/torch/4-02-B-LSTM/
# 62 例子3 建造神经网络 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/3-2-create-NN/
# 63 可视化结果 回归例子 https://morvanzhou.github.io/tutorials/machine-learning/theano/3-3-visualize/
# 64 什么是生成对抗网络 (GAN) https://morvanzhou.github.io/tutorials/machine-learning/torch/4-06-A-GAN/
# 65 读写文件 1 https://morvanzhou.github.io/tutorials/python-basic/basic/08-1-read-file/
# 66 CNN 卷积神经网络 https://morvanzhou.github.io/tutorials/machine-learning/keras/2-3-CNN/
# 67 加速神经网络训练 (Speed Up Training) https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/3-4-A-speed-up-learning/
# 68 Numpy 索引 https://morvanzhou.github.io/tutorials/data-manipulation/np-pd/2-5-np-indexing/
# 69 小例子 https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/2-1-general-rl/
# 70 什么是进化策略 (Evolution Strategy) https://morvanzhou.github.io/tutorials/machine-learning/evolutionary-algorithm/3-00-evolution-strategy/
# 71 RNN 循环神经网络 (分类) https://morvanzhou.github.io/tutorials/machine-learning/torch/4-02-RNN-classification/
# 72 图中图 https://morvanzhou.github.io/tutorials/data-manipulation/plt/4-3-plot-in-plot/
# 73 什么是 LSTM 循环神经网络 https://morvanzhou.github.io/tutorials/machine-learning/keras/2-4-B-LSTM/
# 74 函数参数 https://morvanzhou.github.io/tutorials/python-basic/basic/05-2-def-parameters/
# 75 遗传算法 (Genetic Algorithm) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/5-01-genetic-algorithm/
# 76 Saver 保存读取 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-06-save/
# 77 Dropout 解决 overfitting https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-02-dropout/
# 78 什么是循环神经网络 RNN (Recurrent Neural Network) https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-07-A-RNN/
# 79 从头开始做一个汽车状态分类器1: 分析数据 https://morvanzhou.github.io/tutorials/machine-learning/ML-practice/build-car-classifier-from-scratch1/
# 80 什么是过拟合 (Overfitting) https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-02-A-overfitting/
# 81 变量 (Variable) https://morvanzhou.github.io/tutorials/machine-learning/torch/2-02-variable/
# 82 回到从前 (checkout 针对单个文件) https://morvanzhou.github.io/tutorials/others/git/3-2-checkout/
# 83 科普: 神经网络的黑盒不黑 https://morvanzhou.github.io/tutorials/machine-learning/torch/1-1-D-feature-representation/
# 84 课程要求 https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/1-2-requirment/
# 85 循环神经网络 RNN (Recurrent Neural Network) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/2-3-RNN/
# 86 生成对抗网络 (GAN) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/2-6-GAN/
# 87 threading 什么是多线程 https://morvanzhou.github.io/tutorials/python-basic/basic/13-05-threading/
# 88 AutoEncoder (自编码/非监督学习) https://morvanzhou.github.io/tutorials/machine-learning/torch/4-04-autoencoder/
# 89 读写文件 2 https://morvanzhou.github.io/tutorials/python-basic/basic/08-2-read-file2/
# 90 读写文件 3 https://morvanzhou.github.io/tutorials/python-basic/basic/08-3-read-file3/
# 91 什么是循环神经网络 RNN (Recurrent Neural Network) https://morvanzhou.github.io/tutorials/machine-learning/keras/2-4-A-RNN/
# 92 线程锁 Lock https://morvanzhou.github.io/tutorials/python-basic/threading/6-lock/
# 93 从头开始做一个机器手臂2 写静态环境 https://morvanzhou.github.io/tutorials/machine-learning/ML-practice/RL-build-arm-from-scratch2/
# 94 Function 用法 https://morvanzhou.github.io/tutorials/machine-learning/theano/2-2-function/
# 95 Q-learning 算法更新 https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/2-2-tabular-q1/
# 96 Regression 回归例子 https://morvanzhou.github.io/tutorials/machine-learning/theano/3-2-regression/
# 97 Save & reload 保存提取 https://morvanzhou.github.io/tutorials/machine-learning/keras/3-1-save/
# 98 NEAT 监督学习 https://morvanzhou.github.io/tutorials/machine-learning/evolutionary-algorithm/4-02-neat-supervised-learning/
# 99 Prioritized Experience Replay (DQN) (Tensorflow) https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/4-6-prioritized-replay/
# 100 Activation function 激励函数 https://morvanzhou.github.io/tutorials/machine-learning/theano/2-4-activation/
# 101 定义 Layer 类 https://morvanzhou.github.io/tutorials/machine-learning/theano/3-1-layer/
# 102 CNN 卷积神经网络 3 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-05-CNN3/
# 103 自己的模块 https://morvanzhou.github.io/tutorials/python-basic/basic/12-2-personal-module/
# 104 Natural Evolution Strategy https://morvanzhou.github.io/tutorials/machine-learning/evolutionary-algorithm/3-03-evolution-strategy-natural-evolution-strategy/
# 105 给你的 Ubuntu 安装软件 https://morvanzhou.github.io/tutorials/others/linux-basic/1-4-install-software/
# 106 Distributed Proximal Policy Optimization (DPPO) (Tensorflow) https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/6-4-DPPO/
# 107 什么是激励函数 (Activation Function) https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/2-6-A-activation-function/
# 108 什么是 Sarsa https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/3-1-A-sarsa/
# 109 科普: 神经网络的黑盒不黑 https://morvanzhou.github.io/tutorials/machine-learning/theano/1-1-D-feature-representation/
# 110 RNN Regressor 循环神经网络 https://morvanzhou.github.io/tutorials/machine-learning/keras/2-5-RNN-LSTM-Regressor/
# 111 class 类 https://morvanzhou.github.io/tutorials/python-basic/basic/09-1-class/
# 112 交叉验证 2 Cross-validation https://morvanzhou.github.io/tutorials/machine-learning/sklearn/3-3-cross-validation2/
# 113 自己的云计算, 多电脑共享你云端文件 https://morvanzhou.github.io/tutorials/others/linux-basic/5-02-share-folder/
# 114 神经网络在做什么 https://morvanzhou.github.io/tutorials/machine-learning/theano/1-3-NN-job/
# 115 进程池 Pool https://morvanzhou.github.io/tutorials/python-basic/multiprocessing/5-pool/
# 116 Torch 或 Numpy https://morvanzhou.github.io/tutorials/machine-learning/torch/2-01-torch-numpy/
# 117 Numpy copy & deep copy https://morvanzhou.github.io/tutorials/data-manipulation/np-pd/2-8-np-copy/
# 118 Linux 基本指令 nano 和 cat https://morvanzhou.github.io/tutorials/others/linux-basic/2-04-basic-command/
# 119 Scale 尺度 https://morvanzhou.github.io/tutorials/python-basic/tkinter/2-05-scale/
# 120 Pandas 合并 merge https://morvanzhou.github.io/tutorials/data-manipulation/np-pd/3-7-pd-merge/
# 121 Label & Button 标签和按钮 https://morvanzhou.github.io/tutorials/python-basic/tkinter/2-01-label-button/
# 122 Evolution Strategy 强化学习 https://morvanzhou.github.io/tutorials/machine-learning/evolutionary-algorithm/4-04-evolution-strategy-reinforcement-learning/
# 123 例子 登录窗口2 https://morvanzhou.github.io/tutorials/python-basic/tkinter/3-02-example2/
# 124 过拟合 (Overfitting) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/3-05-overfitting/
# 125 临时修改 (stash) https://morvanzhou.github.io/tutorials/others/git/4-4-stash/
# 126 Policy Gradients https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/4-07-PG/
# 127 回到从前 (reset) https://morvanzhou.github.io/tutorials/others/git/3-1-reset/
# 128 科普: 人工神经网络 VS 生物神经网络 https://morvanzhou.github.io/tutorials/machine-learning/theano/1-1-A-ANN-and-NN/
# 129 BeautifulSoup 解析网页: 基础 https://morvanzhou.github.io/tutorials/data-manipulation/scraping/2-01-beautifulsoup-basic/
# 130 input 输入 https://morvanzhou.github.io/tutorials/python-basic/basic/10-1-input/
# 131 激励函数 Activation Function https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/2-6-activation/
# 132 特征标准化 (Feature Normalization) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/3-02-normalization/
# 133 变量 variable https://morvanzhou.github.io/tutorials/python-basic/basic/02-3-variable/
# 134 Why Keras? https://morvanzhou.github.io/tutorials/machine-learning/keras/1-1-why/
# 135 while 循环 https://morvanzhou.github.io/tutorials/python-basic/basic/03-1-while/
# 136 merge 分支冲突 https://morvanzhou.github.io/tutorials/others/git/4-2-merge-conflict/
# 137 科普: 神经网络的黑盒不黑 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/1-1-D-feature-representation/
# 138 DQN 思维决策 (Tensorflow) https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/4-3-DQN3/
# 139 什么是 Policy Gradients https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/5-1-A-PG/
# 140 Sarsa https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/4-04-sarsa/
# 141 Linux 文件权限 https://morvanzhou.github.io/tutorials/others/linux-basic/3-01-file-permissions/
# 142 什么是 tkinter 窗口 https://morvanzhou.github.io/tutorials/python-basic/basic/13-07-tkinter/
# 143 Pandas 合并 concat https://morvanzhou.github.io/tutorials/data-manipulation/np-pd/3-6-pd-concat/
# 144 Linux 基本指令 mkdir, rmdir 和 rm https://morvanzhou.github.io/tutorials/others/linux-basic/2-03-basic-command/
# 145 什么是神经网络 (Neural Network) https://morvanzhou.github.io/tutorials/machine-learning/keras/1-1-B-NN/
# 146 Sarsa 算法更新 https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/3-1-tabular-sarsa1/
# 147 例子 配对句子 https://morvanzhou.github.io/tutorials/machine-learning/evolutionary-algorithm/2-02-genetic-algorithm-match-phrase/
# 148 什么是 Q Leaning https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/2-2-A-q-learning/
# 149 什么是迁移学习 Transfer Learning https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-16-A-tranfer-learning/
# 150 Menubar 菜单 https://morvanzhou.github.io/tutorials/python-basic/tkinter/2-08-menubar/
# 151 CNN 卷积神经网络 2 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-04-CNN2/
# 152 加速爬虫: 异步加载 Asyncio https://morvanzhou.github.io/tutorials/data-manipulation/scraping/4-02-asyncio/
# 153 保存模型 https://morvanzhou.github.io/tutorials/machine-learning/sklearn/3-5-save/
# 154 正则表达式 https://morvanzhou.github.io/tutorials/python-basic/basic/13-10-regular-expression/
# 155 什么是 Actor Critic https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/6-1-A-AC/
# 156 Sarsa(lambda) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/4-05-sarsa-lambda/
# 157 NEAT 强化学习 https://morvanzhou.github.io/tutorials/machine-learning/evolutionary-algorithm/4-03-neat-reinforcement-learning/
# 158 def 函数 https://morvanzhou.github.io/tutorials/python-basic/basic/05-1-def/
# 159 安装 https://morvanzhou.github.io/tutorials/python-basic/basic/01-1-install/
# 160 DQN 神经网络 (Tensorflow) https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/4-2-DQN2/
# 161 Microbial Genetic Algorithm https://morvanzhou.github.io/tutorials/machine-learning/evolutionary-algorithm/2-04-microbial-genetic-algorithm/
# 162 添加线程 Thread https://morvanzhou.github.io/tutorials/python-basic/threading/2-add-thread/
# 163 什么是卷积神经网络 CNN (Convolutional Neural Network) https://morvanzhou.github.io/tutorials/machine-learning/keras/2-3-A-CNN/
# 164 Batch Normalization 批标准化 https://morvanzhou.github.io/tutorials/machine-learning/torch/5-04-batch-normalization/
# 165 for 循环 https://morvanzhou.github.io/tutorials/python-basic/basic/03-2-for/
# 166 检验神经网络 (Evaluation) https://morvanzhou.github.io/tutorials/machine-learning/sklearn/3-2-A-Evaluate-NN/
# 167 小练习: 爬百度百科 https://morvanzhou.github.io/tutorials/data-manipulation/scraping/2-04-practice-baidu-baike/
# 168 GAN (Generative Adversarial Nets 生成对抗网络) https://morvanzhou.github.io/tutorials/machine-learning/torch/4-06-GAN/
# 169 什么是 Multiprocessing https://morvanzhou.github.io/tutorials/python-basic/multiprocessing/1-why/
# 170 Dropout 缓解过拟合 https://morvanzhou.github.io/tutorials/machine-learning/torch/5-03-dropout/
# 171 RNN 循环神经网络 (回归) https://morvanzhou.github.io/tutorials/machine-learning/torch/4-03-RNN-regression/
# 172 全局 & 局部 变量 https://morvanzhou.github.io/tutorials/python-basic/basic/06-1-global-local/
# 173 CNN 卷积神经网络 1 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-03-CNN1/
# 174 例子2 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/2-2-example2/
# 175 强化学习 (Reinforcement Learning) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/4-01-RL/
# 176 什么是卷积神经网络 CNN (Convolutional Neural Network) https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-03-A-CNN/
# 177 进化策略 https://morvanzhou.github.io/tutorials/machine-learning/evolutionary-algorithm/3-01-evolution-strategy/
# 178 保存提取 https://morvanzhou.github.io/tutorials/machine-learning/torch/3-04-save-reload/
# 179 为什么用强化学习 Why? https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/1-1-why/
# 180 存储进程输出 Queue https://morvanzhou.github.io/tutorials/python-basic/multiprocessing/3-queue/
# 181 总结和更多 https://morvanzhou.github.io/tutorials/machine-learning/theano/4-1-summary/
# 182 基础数学运算 https://morvanzhou.github.io/tutorials/python-basic/basic/02-2-basic-math/
# 183 了解网页结构 https://morvanzhou.github.io/tutorials/data-manipulation/scraping/1-01-understand-website/
# 184 Session 会话控制 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/2-3-session/
# 185 Radiobutton 选择按钮 https://morvanzhou.github.io/tutorials/python-basic/tkinter/2-04-radiobutton/
# 186 处理结构 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/2-1-structure/
# 187 Asynchronous Advantage Actor-Critic (A3C) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/4-10-A3C/
# 188 从头开始做一个机器手臂1 搭建结构 https://morvanzhou.github.io/tutorials/machine-learning/ML-practice/RL-build-arm-from-scratch1/
# 189 GIL 不一定有效率 https://morvanzhou.github.io/tutorials/python-basic/threading/5-GIL/
# 190 从头开始做一个汽车状态分类器2: 搭建模型 https://morvanzhou.github.io/tutorials/machine-learning/ML-practice/build-car-classifier-from-scratch2/
# 191 什么是 LSTM 循环神经网络 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-07-B-LSTM/
# 192 什么是激励函数 (Activation Function) https://morvanzhou.github.io/tutorials/machine-learning/torch/2-03-A-activation-function/
# 193 Deep Deterministic Policy Gradient (DDPG) (Tensorflow) https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/6-2-DDPG/
# 194 Pandas 设置值 https://morvanzhou.github.io/tutorials/data-manipulation/np-pd/3-3-pd-assign/
# 195 Linux 基本指令 ls 和 cd https://morvanzhou.github.io/tutorials/others/linux-basic/2-01-basic-command/
# 196 机器学习 (Machine Learning) https://morvanzhou.github.io/tutorials/machine-learning/sklearn/1-1-A-ML/
# 197 模块安装 https://morvanzhou.github.io/tutorials/python-basic/basic/07-1-module-install/
# 198 交叉验证 1 Cross-validation https://morvanzhou.github.io/tutorials/machine-learning/sklearn/3-2-cross-validation1/
# 199 进程锁 Lock https://morvanzhou.github.io/tutorials/python-basic/multiprocessing/7-lock/
# 200 正规化 Normalization https://morvanzhou.github.io/tutorials/machine-learning/sklearn/3-1-normalization/
# 201 figure 图像 https://morvanzhou.github.io/tutorials/data-manipulation/plt/2-2-figure/
# 202 处理不均衡数据 (Imbalanced data) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/3-07-imbalanced-data/
# 203 加速爬虫: 多进程分布式 https://morvanzhou.github.io/tutorials/data-manipulation/scraping/4-01-distributed-scraping/
# 204 什么是神经网络 (Neural Network) https://morvanzhou.github.io/tutorials/machine-learning/torch/1-1-B-NN/
# 205 卷积神经网络 CNN (Convolutional Neural Network) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/2-2-CNN/
# 206 Scatter 散点图 https://morvanzhou.github.io/tutorials/data-manipulation/plt/3-1-scatter/
# 207 pack grid place 放置位置 https://morvanzhou.github.io/tutorials/python-basic/tkinter/2-11-pack-grid-place/
# 208 CNN 卷积神经网络 https://morvanzhou.github.io/tutorials/machine-learning/torch/4-01-CNN/
# 209 什么是过拟合 (Overfitting) https://morvanzhou.github.io/tutorials/machine-learning/theano/3-5-A-overfitting/
# 210 Animation 动画 https://morvanzhou.github.io/tutorials/data-manipulation/plt/5-1-animation/
# 211 什么是 DQN https://morvanzhou.github.io/tutorials/machine-learning/torch/4-05-A-DQN/
# 212 什么是自编码 (Autoencoder) https://morvanzhou.github.io/tutorials/machine-learning/keras/2-6-A-autoencoder/
# 213 什么是多线程 Threading https://morvanzhou.github.io/tutorials/python-basic/threading/1-why/
# 214 RNN LSTM (回归例子) https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-09-RNN3/
# 215 join 功能 https://morvanzhou.github.io/tutorials/python-basic/threading/3-join/
# 216 科普: 人工神经网络 VS 生物神经网络 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/1-1-A-ANN-and-NN/
# 217 优化器 optimizer https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/3-4-optimizer/
# 218 Dueling DQN (Tensorflow) https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/4-7-dueling-DQN/
# 219 什么是 强化学习 (Reinforcement Learning) https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/1-1-A-RL/
# 220 神经网络 梯度下降 https://morvanzhou.github.io/tutorials/machine-learning/keras/1-1-C-gradient-descent/
# 221 什么是自编码 (Autoencoder) https://morvanzhou.github.io/tutorials/machine-learning/torch/4-04-A-autoencoder/
# 222 Sklearn 安装 https://morvanzhou.github.io/tutorials/machine-learning/sklearn/1-2-install/
# 223 messagebox 弹窗 https://morvanzhou.github.io/tutorials/python-basic/tkinter/2-10-messagebox/
# 224 Why Pytorch? https://morvanzhou.github.io/tutorials/machine-learning/torch/1-1-why/
# 225 批训练 https://morvanzhou.github.io/tutorials/machine-learning/torch/3-05-train-on-batch/
# 226 Tensorflow 安装 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/1-2-install/
# 227 第一个版本库 Repository https://morvanzhou.github.io/tutorials/others/git/2-1-repository/
# 228 基本用法 https://morvanzhou.github.io/tutorials/machine-learning/theano/2-1-basic-usage/
# 229 多功能的 Requests https://morvanzhou.github.io/tutorials/data-manipulation/scraping/3-01-requests/
# 230 Tensorboard 可视化好帮手 1 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/4-1-tensorboard1/
# 231 Pandas 基本介绍 https://morvanzhou.github.io/tutorials/data-manipulation/np-pd/3-1-pd-intro/
# 232 从头开始做一个机器手臂3 写动态环境 https://morvanzhou.github.io/tutorials/machine-learning/ML-practice/RL-build-arm-from-scratch3/
# 233 Shared 变量 https://morvanzhou.github.io/tutorials/machine-learning/theano/2-3-shared-variable/
# 234 次坐标轴 https://morvanzhou.github.io/tutorials/data-manipulation/plt/4-4-sencondary-axis/
# 235 设置坐标轴1 https://morvanzhou.github.io/tutorials/data-manipulation/plt/2-3-axis1/
# 236 为什么 Torch 是动态的 https://morvanzhou.github.io/tutorials/machine-learning/torch/5-01-dynamic/
# 237 Github 在线代码管理 https://morvanzhou.github.io/tutorials/others/git/5-1-github/
# 238 Q-learning 思维决策 https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/2-3-tabular-q2/
# 239 为什么用 Matplotlib https://morvanzhou.github.io/tutorials/data-manipulation/plt/1-1-why/
# 240 多维列表 https://morvanzhou.github.io/tutorials/python-basic/basic/11-3-multi-dim-list/
# 241 分支 (branch) https://morvanzhou.github.io/tutorials/others/git/4-1-branch/
# 242 什么是卷积神经网络 CNN (Convolutional Neural Network) https://morvanzhou.github.io/tutorials/machine-learning/torch/4-01-A-CNN/
# 243 什么是 Sarsa(lambda) https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/3-3-A-sarsa-lambda/
# 244 Numpy array 合并 https://morvanzhou.github.io/tutorials/data-manipulation/np-pd/2-6-np-concat/
# 245 什么是 Asynchronous Advantage Actor-Critic (A3C) https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/6-3-A1-A3C/
# 246 用 Tensorflow 可视化梯度下降 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-15-tf-gradient-descent/
# 247 pickle 保存数据 https://morvanzhou.github.io/tutorials/python-basic/basic/13-08-pickle/
# 248 小练习: 下载美图 https://morvanzhou.github.io/tutorials/data-manipulation/scraping/3-03-practice-download-image/
# 249 GPU 加速运算 https://morvanzhou.github.io/tutorials/machine-learning/torch/5-02-GPU/
# 250 选择好特征 (Good Features) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/3-03-choose-feature/
# 251 科普: 神经网络的黑盒不黑 https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/2-7-feature-representation/
# 252 Theano 安装 https://morvanzhou.github.io/tutorials/machine-learning/theano/1-2-install/
# 253 自编码 (Autoencoder) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/2-5-autoencoder/
# 254 list 列表 https://morvanzhou.github.io/tutorials/python-basic/basic/11-2-list/
# 255 什么是 Tkinter https://morvanzhou.github.io/tutorials/python-basic/tkinter/1-1-why/
# 256 Classification 分类学习 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-01-classifier/
# 257 Autoencoder 自编码 https://morvanzhou.github.io/tutorials/machine-learning/keras/2-6-autoencoder/
# 258 通用学习模式 https://morvanzhou.github.io/tutorials/machine-learning/sklearn/2-2-general-pattern/
# 259 DQN https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/4-06-DQN/
# 260 Sarsa-lambda https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/3-3-tabular-sarsa-lambda/
# 261 dictionary 字典 https://morvanzhou.github.io/tutorials/python-basic/basic/11-4-dictionary/
# 262 Pytorch 安装 https://morvanzhou.github.io/tutorials/machine-learning/torch/1-2-install/
# 263 神经网络进化 (Neuro-Evolution) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/5-03-neuro-evolution/
# 264 强化学习方法汇总 (Reinforcement Learning) https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/1-1-B-RL-methods/
# 265 Pandas 导入导出 https://morvanzhou.github.io/tutorials/data-manipulation/np-pd/3-5-pd-to/
# 266 Subplot 分格显示 https://morvanzhou.github.io/tutorials/data-manipulation/plt/4-2-subplot2/
# 267 怎么样从手机 (Android安卓/IOS苹果) 通过 SSH 远程 Linux https://morvanzhou.github.io/tutorials/others/linux-basic/4-03-ssh-from-phone/
# 268 记录修改 (log & diff) https://morvanzhou.github.io/tutorials/others/git/2-2-modified/
# 269 基本用法 https://morvanzhou.github.io/tutorials/data-manipulation/plt/2-1-basic-usage/
# 270 import 模块 https://morvanzhou.github.io/tutorials/python-basic/basic/12-1-import/
# 271 进化策略 (Evolution Strategy) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/5-02-evolution-strategy/
# 272 Regressor 回归 https://morvanzhou.github.io/tutorials/machine-learning/keras/2-1-regressor/
# 273 Policy Gradients 思维决策 (Tensorflow) https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/5-2-policy-gradient-softmax2/
# 274 Listbox 列表部件 https://morvanzhou.github.io/tutorials/python-basic/tkinter/2-03-listbox/
# 275 区分类型 (分类) https://morvanzhou.github.io/tutorials/machine-learning/torch/3-02-classification/
# 276 科普: 人工神经网络 VS 生物神经网络 https://morvanzhou.github.io/tutorials/machine-learning/torch/1-1-A-ANN-and-NN/
# 277 print 功能 https://morvanzhou.github.io/tutorials/python-basic/basic/02-1-print/
# 278 例子 登录窗口1 https://morvanzhou.github.io/tutorials/python-basic/tkinter/3-01-example1/
# 279 批标准化 (Batch Normalization) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/3-08-batch-normalization/
# 280 if else 判断 https://morvanzhou.github.io/tutorials/python-basic/basic/04-2-if-else/
# 281 Linux 基本指令 touch, cp 和 mv https://morvanzhou.github.io/tutorials/others/linux-basic/2-02-basic-command/
# 282 try 错误处理 https://morvanzhou.github.io/tutorials/python-basic/basic/13-02-try/
# 283 Image 图片 https://morvanzhou.github.io/tutorials/data-manipulation/plt/3-4-image/
# 284 sklearn 强大数据库 https://morvanzhou.github.io/tutorials/machine-learning/sklearn/2-3-database/
# 285 例子3 结果可视化 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/3-3-visualize-result/
# 286 Variable 变量 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/2-4-variable/
# 287 DQN 强化学习 https://morvanzhou.github.io/tutorials/machine-learning/torch/4-05-DQN/
# 288 set 找不同 https://morvanzhou.github.io/tutorials/python-basic/basic/13-09-set/
# 289 Subplot 多合一显示 https://morvanzhou.github.io/tutorials/data-manipulation/plt/4-1-subpot1/
# 290 怎么样用 TeamViewer 和 VNC 从远程控制电脑 https://morvanzhou.github.io/tutorials/others/linux-basic/4-04-teamviewer-vnc/
# 291 Why Theano? https://morvanzhou.github.io/tutorials/machine-learning/theano/1-1-why/
# 292 关系拟合 (回归) https://morvanzhou.github.io/tutorials/machine-learning/torch/3-01-regression/
# 293 AlphaGo Zero 为什么更厉害? https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/4-11-AlphaGo-zero/
# 294 continue & break https://morvanzhou.github.io/tutorials/python-basic/basic/13-01-continue-break/
# 295 Why Sklearn? https://morvanzhou.github.io/tutorials/machine-learning/sklearn/1-1-why/
# 296 Numpy array 分割 https://morvanzhou.github.io/tutorials/data-manipulation/np-pd/2-7-np-split/
# 297 Matplotlib 安装 https://morvanzhou.github.io/tutorials/data-manipulation/plt/1-2-install/
# 298 Canvas 画布 https://morvanzhou.github.io/tutorials/python-basic/tkinter/2-07-canvas/
# 299 元组 列表 https://morvanzhou.github.io/tutorials/python-basic/basic/11-1-array-list/
# 300 Classification 分类学习 https://morvanzhou.github.io/tutorials/machine-learning/theano/3-4-classification/
# 301 BeautifulSoup 解析网页: CSS https://morvanzhou.github.io/tutorials/data-manipulation/scraping/2-02-beautifulsoup-css/
# 302 什么是过拟合 (Overfitting) https://morvanzhou.github.io/tutorials/machine-learning/torch/5-03-A-overfitting/
# 303 设置坐标轴2 https://morvanzhou.github.io/tutorials/data-manipulation/plt/2-4-axis2/
# 304 为什么用 Numpy 还是慢, 你用对了吗? https://morvanzhou.github.io/tutorials/data-manipulation/np-pd/4-1-speed-up-numpy/
# 305 DQN 算法更新 (Tensorflow) https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/4-1-DQN1/
# 306 RNN LSTM 循环神经网络 (分类例子) https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-08-RNN2/
# 307 神经网络在干嘛 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/1-3-what-does-NN-do/
# 308 Optimizer 优化器 https://morvanzhou.github.io/tutorials/machine-learning/torch/3-06-optimizer/
# 309 multiprocessing 什么是多进程 https://morvanzhou.github.io/tutorials/python-basic/basic/13-06-multiprocessing/
# 310 例子 登录窗口3 https://morvanzhou.github.io/tutorials/python-basic/tkinter/3-03-example3/
# 311 为什么选 Tensorflow? https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/1-1-why/
# 312 进化算法 简介 https://morvanzhou.github.io/tutorials/machine-learning/evolutionary-algorithm/1-01-intro/
# 313 什么是 Deep Deterministic Policy Gradient (DDPG) https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/6-2-A-DDPG/
# 314 怎么样从 Windows 通过 SSH 远程 Linux https://morvanzhou.github.io/tutorials/others/linux-basic/4-02-ssh-from-windows/
# 315 Actor Critic (Tensorflow) https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/6-1-actor-critic/
# 316 选择学习方法 https://morvanzhou.github.io/tutorials/machine-learning/sklearn/2-1-select-method/
# 317 Pandas 选择数据 https://morvanzhou.github.io/tutorials/data-manipulation/np-pd/3-2-pd-indexing/
# 318 Deep Deterministic Policy Gradient (DDPG) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/4-09-DDPG/
# 319 强化学习方法汇总 (Reinforcement Learning) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/4-02-RL-methods/
# 320 Numpy 基础运算1 https://morvanzhou.github.io/tutorials/data-manipulation/np-pd/2-3-np-math1/
# 321 Annotation 标注 https://morvanzhou.github.io/tutorials/data-manipulation/plt/2-6-annotation/
# 322 Asynchronous Advantage Actor-Critic (A3C) (Tensorflow) https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/6-3-A3C/
# 323 if 判断 https://morvanzhou.github.io/tutorials/python-basic/basic/04-1-if/
# 324 神经网络 梯度下降 https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/2-8-gradient-descent/
# 325 LSTM RNN 循环神经网络 (LSTM) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/2-4-LSTM/
# 326 L1 / L2 正规化 (Regularization) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/3-09-l1l2regularization/
# 327 Numpy 和 Pandas 安装 https://morvanzhou.github.io/tutorials/data-manipulation/np-pd/1-2-install/
# 328 Tensorboard 可视化好帮手 2 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/4-2-tensorboard2/
# 329 例子 旅行商人问题 (Travel Sales Problem) https://morvanzhou.github.io/tutorials/machine-learning/evolutionary-algorithm/2-03-genetic-algorithm-travel-sales-problem/
# 330 检验神经网络 (Evaluation) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/3-01-Evaluate-NN/
# 331 Why Linux? https://morvanzhou.github.io/tutorials/others/linux-basic/1-1-why/
# 332 什么是神经网络 (Neural Network) https://morvanzhou.github.io/tutorials/machine-learning/theano/1-1-B-NN/
# 333 什么是批标准化 (Batch Normalization) https://morvanzhou.github.io/tutorials/machine-learning/torch/5-04-A-batch-normalization/
# 334 效率对比 threading & multiprocessing https://morvanzhou.github.io/tutorials/python-basic/multiprocessing/4-comparison/
# 335 3D 数据 https://morvanzhou.github.io/tutorials/data-manipulation/plt/3-5-3d/
# 336 Why Git? https://morvanzhou.github.io/tutorials/others/git/1-1-why/
# 337 scope 命名方法 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-12-scope/
# 338 函数默认参数 https://morvanzhou.github.io/tutorials/python-basic/basic/05-3-def-default-parameters/
# 339 自编码 Autoencoder (非监督学习) https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-11-autoencoder/
# 340 Contours 等高线图 https://morvanzhou.github.io/tutorials/data-manipulation/plt/3-3-contours/
# 341 Git 安装 https://morvanzhou.github.io/tutorials/others/git/1-2-install/
# 342 加速神经网络训练 (Speed Up Training) https://morvanzhou.github.io/tutorials/machine-learning/torch/3-06-A-speed-up-learning/
# 343 Why Numpy & Pandas? https://morvanzhou.github.io/tutorials/data-manipulation/np-pd/1-1-why/
# 344 RNN 循环神经网络 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-07-RNN1/
# 345 Numpy 属性 https://morvanzhou.github.io/tutorials/data-manipulation/np-pd/2-1-np-attributes/
# 346 激励函数 (Activation Function) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/3-04-activation-function/
# 347 神经网络 (Neural Network) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/2-1-NN/
# 348 机器学习 (Machine Learning) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/1-1-machine-learning/
# 349 (1+1)-ES https://morvanzhou.github.io/tutorials/machine-learning/evolutionary-algorithm/3-02-evolution-strategy-1+1-ES/
# 350 BeautifulSoup 解析网页: 正则表达 https://morvanzhou.github.io/tutorials/data-manipulation/scraping/2-03-beautifulsoup-regex/
# 351 Checkbutton 勾选项 https://morvanzhou.github.io/tutorials/python-basic/tkinter/2-06-checkbutton/
# 352 Legend 图例 https://morvanzhou.github.io/tutorials/data-manipulation/plt/2-5-lagend/
# 353 神经网络 梯度下降 https://morvanzhou.github.io/tutorials/machine-learning/theano/1-1-C-gradient-descent/
# 354 Keras 安装 https://morvanzhou.github.io/tutorials/machine-learning/keras/1-2-install/
# 355 科普: 人工神经网络 VS 生物神经网络 https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/2-0-ANN-and-NN/
# 356 安装 Ubuntu 17.10 https://morvanzhou.github.io/tutorials/others/linux-basic/1-2-install/
# 357 例子3 添加层 def add_layer() https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/3-1-add-layer/
# 358 Frame 框架 https://morvanzhou.github.io/tutorials/python-basic/tkinter/2-09-frame/
# 359 Classifier 分类 https://morvanzhou.github.io/tutorials/machine-learning/keras/2-2-classifier/
# 360 神经进化 https://morvanzhou.github.io/tutorials/machine-learning/evolutionary-algorithm/4-01-neuro-evolution/
# 361 Numpy 基础运算2 https://morvanzhou.github.io/tutorials/data-manipulation/np-pd/2-4-np-math2/
# 362 rebase 分支冲突 https://morvanzhou.github.io/tutorials/others/git/4-3-rebase/
# 363 科普: 神经网络的黑盒不黑 https://morvanzhou.github.io/tutorials/machine-learning/keras/1-1-D-feature-representation/
# 364 RNN Classifier 循环神经网络 https://morvanzhou.github.io/tutorials/machine-learning/keras/2-4-RNN-classifier/
# 365 Q Leaning https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/4-03-q-learning/
# 366 加速神经网络训练 (Speed Up Training) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/3-06-speed-up-learning/
# 367 Sarsa 思维决策 https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/3-2-tabular-sarsa2/
# 368 Actor Critic https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/4-08-AC/
# 369 添加进程 Process https://morvanzhou.github.io/tutorials/python-basic/multiprocessing/2-add/
# 370 RNN LSTM (回归例子可视化) https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-10-RNN4/
# 371 激励函数 (Activation) https://morvanzhou.github.io/tutorials/machine-learning/torch/2-03-activation/
# 372 兼容 backend https://morvanzhou.github.io/tutorials/machine-learning/keras/1-3-backend/
# 373 从头开始做一个机器手臂4 加入强化学习算法 https://morvanzhou.github.io/tutorials/machine-learning/ML-practice/RL-build-arm-from-scratch4/
# 374 自己的云计算, 把 Linux 当成你的云计算平台 https://morvanzhou.github.io/tutorials/others/linux-basic/5-01-remote-learning/
# 375 Pandas 处理丢失数据 https://morvanzhou.github.io/tutorials/data-manipulation/np-pd/3-4-pd-nan/
# 376 Regularization 正规化 https://morvanzhou.github.io/tutorials/machine-learning/theano/3-5-regularization/
# 377 什么是循环神经网络 RNN (Recurrent Neural Network) https://morvanzhou.github.io/tutorials/machine-learning/torch/4-02-A-RNN/
# 378 什么是神经网络 (Neural Network) https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/1-1-B-NN/
# 379 下载文件 https://morvanzhou.github.io/tutorials/data-manipulation/scraping/3-02-download/
# 380 Batch Normalization 批标准化 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-13-BN/
# 381 遗传算法 https://morvanzhou.github.io/tutorials/machine-learning/evolutionary-algorithm/2-01-genetic-algorithm/
# 382 Save 保存 提取 https://morvanzhou.github.io/tutorials/machine-learning/theano/3-6-save/
# 383 科普: 人工神经网络 VS 生物神经网络 https://morvanzhou.github.io/tutorials/machine-learning/keras/1-1-A-ANN-and-NN/
# 384 交叉验证 3 Cross-validation https://morvanzhou.github.io/tutorials/machine-learning/sklearn/3-4-cross-validation3/
# 385 快速搭建法 https://morvanzhou.github.io/tutorials/machine-learning/torch/3-03-fast-nn/
# 386 Policy Gradients 算法更新 (Tensorflow) https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/5-1-policy-gradient-softmax1/
# Total time: 92.4 s
